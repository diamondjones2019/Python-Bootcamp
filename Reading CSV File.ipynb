# %%
pwd
# Out:
# 'C:\\Users\\Diamond\\Documents\\Jupyter Files'

# %%
import csv

# %%
#Open the file 
data = open('credit.csv')


#Calling the csv.reader
csv_data = csv.reader(data)


#reformatting the python object list of lists 
data_lines = list(csv_data)

# %%
data_lines
# Out:
# [['',
#   'ID',
#   'Income',
#   'Limit',
#   'Rating',
#   'Cards',
#   'Age',
#   'Education',
#   'Gender',
#   'Student',
#   'Married',
#   'Ethnicity',
#   'Balance'],
#  ['1',
#   '1',
#   '14.891',
#   '3606',
#   '283',
#   '2',
#   '34',
#   '11',
#   ' Male',
#   'No',
#   'Yes',
#   'Caucasian',
#   '333'],
#  ['2',
#   '2',
#   '106.025',
#   '6645',
#   '483',
#   '3',
#   '82',
#   '15',
#   'Female',
#   'Yes',
#   'Yes',
#   'Asian',
#   '903'],
#  ['3',
#   '3',
#   '104.593',
#   '7075',
#   '514',
#   '4',
#   '71',
#   '11',
#   ' Male',
#   'No',
#   'No',
#   'Asian',
#   '580'],
#  ['4',
#   '4',
#   '148.924',
#   '9504',
#   '681',
#   '3',
#   '36',
#   '11',
#   'Female',
#   'No',
#   'No',
#   'Asian',
#   '964'],
#  ['5',
#   '5',
#   '55.882',
#   '4897',
#   '357',
#   '2',
#   '68',
#   '16',
#   ' Male',
#   'No',
#   'Yes',
#   'Caucasian',
#   '331'],
#  ['6',
#   '6',
#   '80.18',
#   '8047',
#   '569',
#   '4',
#   '77',
#   '10',
#   ' Male',
# ...

# %%
data_lines[0]
# Out:
# ['',
#  'ID',
#  'Income',
#  'Limit',
#  'Rating',
#  'Cards',
#  'Age',
#  'Education',
#  'Gender',
#  'Student',
#  'Married',
#  'Ethnicity',
#  'Balance']

# %%
#wanting a specific line
data_lines[3]
# Out:
# ['3',
#  '3',
#  '104.593',
#  '7075',
#  '514',
#  '4',
#  '71',
#  '11',
#  ' Male',
#  'No',
#  'No',
#  'Asian',
#  '580']
